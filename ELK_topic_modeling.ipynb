# %%
import numpy as np
np.random.seed(2020)
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import alpino
from nltk.tag import UnigramTagger
from random import shuffle
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from datetime import datetime
from statistics import mean

# %%
DF = pd.read_json('ELK.json', encoding='utf-8-sig', lines=True)
print(DF.shape)
DF.groupby('shop').count()
# Out:
# (324324, 8)
#                                 globalId  authorAgeRange  submissionDateTime  \
# shop
# Audio en Televisie                 50387           32751               50387
# Camera en Accessoires              26524           16804               26524
# Computer Accessoires               54291           35934               54291
# Computer Hardware                  10476            7468               10476
# Groot Huishoudelijk                15792           11629               15792
# Klein Huishoudelijk                84583           63277               84583
# Mobiele Hardware en Wearables      30238           20715               30238
# Telefoon en Tablet Accessoires     52033           34582               52033
#
#                                 cluster  rating   text  title
# shop
# Audio en Televisie                50387   50387  50387  50384
# Camera en Accessoires             26524   26524  26524  26524
# Computer Accessoires              54291   54291  54291  54290
# Computer Hardware                 10476   10476  10476  10476
# Groot Huishoudelijk               15792   15792  15792  15792
# Klein Huishoudelijk               84583   84583  84583  84583
# Mobiele Hardware en Wearables     30238   30238  30238  30236
# Telefoon en Tablet Accessoires    52033   52033  52033  52033

# %%
DF['submissionDateTime'] = pd.to_datetime(DF['submissionDateTime'], yearfirst=True, utc=True)
DF = DF[['globalId', 'authorAgeRange', 'submissionDateTime', 'shop', 'cluster', 'rating', 'text', 'title']]

# %% [markdown]
# **SORT BY MONTH AND POLARITY** (only takes into accounts 5 or 1 star reviews)

# %%
# MSB_january = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'January'].to_numpy()]
january_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'January')&(DF['rating'] ==5)].to_numpy()]
january_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'January')&(DF['rating'] ==1)].to_numpy()]

# MSB_february = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'February'].to_numpy()]
february_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'February')&(DF['rating'] ==5)].to_numpy()]
february_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'February')&(DF['rating'] ==1)].to_numpy()]

# MSB_march = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'March'].to_numpy()]
march_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'March')&(DF['rating'] ==5)].to_numpy()]
march_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'March')&(DF['rating'] ==1)].to_numpy()]

# MSB_april = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'April'].to_numpy()]
april_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'April')&(DF['rating'] ==5)].to_numpy()]
april_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'April')&(DF['rating'] ==1)].to_numpy()]

# MSB_may = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'May'].to_numpy()]
may_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'May')&(DF['rating'] ==5)].to_numpy()]
may_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'May')&(DF['rating'] ==1)].to_numpy()]

# MSB_june = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'June'].to_numpy()]
june_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'June')&(DF['rating'] ==5)].to_numpy()]
june_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'June')&(DF['rating'] ==1)].to_numpy()]

# MSB_july = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'July'].to_numpy()]
july_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'July')&(DF['rating'] ==5)].to_numpy()]
july_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'July')&(DF['rating'] ==1)].to_numpy()]

# MSB_august = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'August'].to_numpy()]
august_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'August')&(DF['rating'] ==5)].to_numpy()]
august_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'August')&(DF['rating'] ==1)].to_numpy()]

# MSB_september = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'September'].to_numpy()]
september_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'September')&(DF['rating'] ==5)].to_numpy()]
september_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'September')&(DF['rating'] ==1)].to_numpy()]

# MSB_october = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'October'].to_numpy()]
october_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'October')&(DF['rating'] ==5)].to_numpy()]
october_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'October')&(DF['rating'] ==1)].to_numpy()]

# MSB_november = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'November'].to_numpy()]
november_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'November')&(DF['rating'] ==5)].to_numpy()]
november_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'November')&(DF['rating'] ==1)].to_numpy()]

# MSB_december = [x for x in DF.loc[DF['submissionDateTime'].dt.strftime('%B') == 'December'].to_numpy()]
december_pos = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'December')&(DF['rating'] ==5)].to_numpy()]
december_neg = [x for x in DF.loc[(DF['submissionDateTime'].dt.strftime('%B') == 'December')&(DF['rating'] ==1)].to_numpy()]

pos = [x for x in DF.loc[DF['rating'] ==5].to_numpy()]
neg = [x for x in DF.loc[DF['rating'] ==1].to_numpy()]

# %%
def main_func(XX):
    obj_analysis = XX
    texts = [item[6] for item in obj_analysis]
    labels = [item[5] for item in obj_analysis]
    labels = [1 if i > 3 else 0 for i in labels]
    def preprocessing(text, pos_tags=False):
        # tokenize into words
        tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]   
        stop = stopwords.words('dutch')  # remove stopwords
        stop.extend(['mee', 'het', 'erg', 'wel', 'zeer', 'wij', 'ik', 'ben', 'jij', 'jullie', 'echt', 
                           'wel', 'heel', 'erg', 'mee', 'dus', 'maar']) #extra stopwords     
        tokens = [token for token in tokens if token not in stop]
        tokens = [word for word in tokens if len(word) >= 3] # remove words less than three characters
        tokens = [word.lower() for word in tokens] # remove capitalization
        lmtzr = WordNetLemmatizer()
        tokens = [lmtzr.lemmatize(word) for word in tokens] # lemmatizing
        preprocessed_text= ' '.join(tokens)
        return preprocessed_text

    def preprocesser(list_of_texts): # turning lists into preprocessed lists
        new = []
        for item in list_of_texts:
            new += [preprocessing(item)]
        return new
    
    corpus = [r for r in preprocesser(texts)]

    #selecting documents with highest subjectivity, based on relative number of present adjectives
    training_corpus = alpino.tagged_sents() # dutch training corpus
    unitagger = UnigramTagger(training_corpus)
    pos_tag = unitagger.tag
    corpus_POS = []  
    for item in corpus:
        tokens = nltk.word_tokenize(item)
        pos_item = pos_tag(tokens)
        new_sent = ['_'.join(t) for t in pos_item if t[1] is not None]
        corpus_POS += [new_sent]
    corpus_POS
    
    ADJ_list = [(1+i.count('adj')) / len(i) for i in corpus_POS] # relative number of adjectives per document
    ADJ_indices = [i for i in range(len(ADJ_list)) if ADJ_list[i] > mean(ADJ_list)] # highly subjective document indexes  

    corpus = [corpus[i] for i in ADJ_indices]
    shuffle(corpus)
    
    vectorizer = CountVectorizer(min_df=4, max_df=0.3, ngram_range=(1,1))
    X = vectorizer.fit_transform(corpus)
    X = pd.DataFrame(X.todense(),columns=vectorizer.get_feature_names())
    
    lda_model = LatentDirichletAllocation(n_components=3, max_iter=10, learning_decay=0.7)
    doc_topic = lda_model.fit_transform(X)

    def display_topics(model, feature_names, no_top_words):
        with open('results_topics_ELK.txt', 'a', encoding='utf-8-sig') as file: 
            file.write(str(datetime.now()) + '\n')
            if len(np.unique(np.array(obj_analysis)[:,3])) == 1:  #adds store specific
                file.write(str(obj_analysis[0][3]) + ' | ') 
            file.write(str(obj_analysis[0][4])
                   + str(' | Positive | ' + str(obj_analysis[0][2]) + '\n\n' if obj_analysis[0][5] > 3 
                     else ' | Negative | '+ str(obj_analysis[0][2]) + '\n\n'))

            for topic_idx, topic in enumerate(model.components_):
                print("Topic %d:" % (topic_idx)," ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]) + '\n')
                file.write("Topic %d: " % (topic_idx))    
                file.write(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])+'\n')              
        
            # Log Likelyhood: Higher the better
            print("Log Likelihood: ", lda_model.score(X))
            file.write("Log Likelihood: " + str(lda_model.score(X))+ ' \n')
            # Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
            print("Perplexity: ", lda_model.perplexity(X))
            file.write("Perplexity: " + str(lda_model.perplexity(X))+ ' \n')
            # See model parameters
            print(lda_model.get_params())
            file.write(str(lda_model.get_params())+ ' \n')
            file.write('\n\n\n')
            
    no_top_words = 20
    feature_names = vectorizer.get_feature_names()
    display_topics(lda_model, feature_names, no_top_words)

# %%
main_func(december_neg)
# Out:
# Topic 0: scherm werkt het past hoesje helaas telefoon goed zit waardoor helemaal ook gsm alleen blijft protector gaat terug mooi zitten
#
# Topic 1: product het goed hoesje dit gebruik kwaliteit telefoon slecht bol jammer los apparaat echter zit zitten toestel com binnen prijs
#
# Topic 2: kabel geluid slecht geld kwaliteit goed keer slechte jaar het doet gekocht kapot binnen gebruiken maakt kopen helaas niet apparaat
#
# Log Likelihood:  -147642.30935581704
# Perplexity:  956.4739013795825
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
my_list = [january_pos, january_neg,
          february_pos, february_neg,
          march_pos, march_neg,
          april_pos, april_neg,
          may_pos, may_neg,
           june_pos, june_neg,
           july_pos, july_neg,
           august_pos, august_neg,
           september_pos, september_neg,
           october_pos, october_neg, 
           november_pos, november_neg,
           december_pos, december_neg
          ]

# %%
for item in my_list:
    main_func(item)
# Out:
# Topic 0: apparaat het makkelijk gebruik snel geluid super maken stofzuiger handig aanrader blij tevreden mooi prima koffie goede een zeker schoon
#
# Topic 1: het telefoon werkt goede prima prijs snel gebruik via laptop mooi perfect kwaliteit bol makkelijk scherm super geluid hoesje aanrader
#
# Topic 2: het gebruik gaat mooi muis camera vind zeker fijn hand goede lang handig makkelijk geluid zit werkt snel foto prima
#
# Log Likelihood:  -3807258.4324339516
# Perplexity:  2067.9649602625723
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: hoesje goed het scherm telefoon waardoor zit past product los screenprotector kwaliteit zitten iphone protector slecht plastic komt geld ziet
#
# Topic 1: bol terug product keer com besteld artikel weer goed retour helaas nieuwe kapot het eerste binnen gaat dit geld gekocht
#
# Topic 2: apparaat het werkt goed weer gebruik gaat keer jaar toestel slecht alleen doet gewoon helaas gekocht geluid dit product kopen
#
# Log Likelihood:  -659909.7059645699
# Perplexity:  1487.0843801132908
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: werkt het telefoon goede prijs via snel scherm prima muis gebruik laptop super kwaliteit tevreden bol perfect makkelijk zit zeker
#
# Topic 1: gebruik het snel makkelijk apparaat stofzuiger gaat tevreden lang handig laptop super prima een weer werkt blij doet aanrader zeker
#
# Topic 2: het geluid apparaat mooi gebruik makkelijk goede prijs kwaliteit prima gaat zeker super handig zit camera toestel vind aanrader maken
#
# Log Likelihood:  -2789607.536605377
# Perplexity:  2032.0504745275668
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: apparaat goed weer het keer jaar product helaas terug gaat gebruik gekocht eerste nieuwe maar gebruikt slecht jammer doet gewoon
#
# Topic 1: hoesje telefoon het kwaliteit scherm zit goed waardoor slecht toestel batterij kabel werkt snel slechte geld gaat product los helaas
#
# Topic 2: werkt goed het product bol geluid com dit terug scherm helaas via gekocht telefoon staat helemaal oortjes alleen keer geld
#
# Log Likelihood:  -515344.35317631956
# Perplexity:  1460.4368301036993
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: geluid goede het prijs bol werkt via com prima gebruik super kwaliteit tevreden zeker kabel aanrader deze muziek een gekocht
#
# Topic 1: apparaat gebruik het makkelijk snel maken super handig mooi schoon prima een koffie tevreden werkt blij aanrader gebruiken doet fijn
#
# Topic 2: het telefoon mooi laptop gebruik snel scherm toestel goede zit makkelijk hoesje prijs werkt kwaliteit muis prima super perfect gaat
#
# Log Likelihood:  -3042774.5793103557
# Perplexity:  1966.9151963590805
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: scherm het hoesje telefoon goed product zit screenprotector geld kapot protector waardoor kwaliteit slecht terug eerste besteld dit zitten past
#
# Topic 1: apparaat goed het keer weer gebruik gaat helaas jaar doet slecht muis gewoon zit helemaal dit kopen eerste steed vind
#
# Topic 2: werkt het product kabel telefoon usb alleen geld goed terug gekocht laptop verbinding helaas kopen weer bol geluid slecht dit
#
# Log Likelihood:  -554523.3934442261
# Perplexity:  1462.808305993877
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: het snel werkt telefoon gebruik laptop scherm toestel prima via usb gaat foto prijs goede muis dit deze camera makkelijk
#
# Topic 1: het gebruik apparaat makkelijk snel super bol tevreden maken handig zeker blij werkt com gaat prima goede stofzuiger aanrader gebruiken
#
# Topic 2: geluid het mooi goede kwaliteit zit prijs telefoon makkelijk prima super hoesje perfect zeker vind gebruik mooie zitten koffie koptelefoon
#
# Log Likelihood:  -2468753.9540406084
# Perplexity:  1953.4017331304462
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: keer telefoon weer werkt goed hoesje gekocht het terug binnen helaas jaar kapot apparaat doet gebruik maanden gewoon helemaal alleen
#
# Topic 1: het apparaat product bol artikel com kwaliteit koffie goed geluid plastic staat gaat retour gebruik slecht helaas brood dit zoals
#
# Topic 2: scherm het goed product protector toestel screenprotector zit slecht telefoon gewoon niet randen kopen past zitten printer foto blijft alle
#
# Log Likelihood:  -404245.47429470427
# Perplexity:  1381.872366669661
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: het gebruik apparaat makkelijk camera maken snel foto mooi super koffie prima een laptop handig goede maakt mooie aanrader tevreden
#
# Topic 1: het goede telefoon bol makkelijk snel super hoesje prijs com perfect mooi stofzuiger muis gebruik tevreden werkt prima zit kwaliteit
#
# Topic 2: het geluid gebruik werkt apparaat goede prijs gaat prima zeker toestel via telefoon snel kwaliteit makkelijk muziek mooi zit tevreden
#
# Log Likelihood:  -2810888.530320768
# Perplexity:  2023.8491385356645
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: werkt het product apparaat alleen helaas staat goed gaat weer toestel gewoon dit muis bol slecht gebruik echter geeft gebruiken
#
# Topic 1: scherm goed het geluid zit apparaat protector screenprotector waardoor product geld glas past zitten kopen dit kwaliteit slecht klein alleen
#
# Topic 2: telefoon hoesje keer jaar goed kapot weer gekocht binnen het terug batterij maanden gebruik weken eerste twee helemaal helaas snel
#
# Log Likelihood:  -408904.9723087937
# Perplexity:  1326.6641993104377
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: het gebruik makkelijk toestel snel scherm telefoon mooi maken apparaat handig zit super werkt zeker tevreden een dit ook hoesje
#
# Topic 1: apparaat gebruik het snel foto bol camera goede makkelijk werkt prijs tevreden super com prima kwaliteit koffie product gaat weer
#
# Topic 2: geluid het goede gebruik prijs mooi super prima kwaliteit zeker werkt makkelijk gaat zit muziek muis stofzuiger aanrader laptop via
#
# Log Likelihood:  -2836676.2175864005
# Perplexity:  2010.3619229274682
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: telefoon werkt weer gekocht batterij goed gaat toestel slecht keer het jaar app gewoon helemaal bol kopen alleen zit opladen
#
# Topic 1: apparaat het keer weer product helaas al goed geld werkt bol gaat artikel terug dit krijg slecht gebruikt twee geluid
#
# Topic 2: het goed scherm hoesje product kwaliteit telefoon zitten zit helaas slecht past kabel protector screenprotector los jammer waardoor geld geluid
#
# Log Likelihood:  -428578.94599878613
# Perplexity:  1344.767073663311
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: geluid het goede werkt via prima prijs bol kwaliteit gebruik com super snel mooi makkelijk kabel zeker muziek aanrader speaker
#
# Topic 1: telefoon het camera foto gebruik mooi goede scherm toestel makkelijk snel handig kwaliteit vind gaat hoesje prima prijs mooie zeker
#
# Topic 2: het apparaat gebruik makkelijk snel stofzuiger muis handig hij prima werkt gaat maken tevreden een laptop super doet mooi maakt
#
# Log Likelihood:  -3100456.5533328657
# Perplexity:  1978.9863136756974
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: apparaat weer keer het bol goed werkt helaas product gekocht terug com alleen batterij nieuwe gaat jaar eerste doet kabel
#
# Topic 1: hoesje het goed zit telefoon waardoor keer past werkt dit gewoon zitten artikel product gaat valt eerste ventilator plastic mooi
#
# Topic 2: scherm telefoon product kwaliteit het slecht goed protector los screenprotector slechte geld komt foto gewoon glas zit waardoor staat randen
#
# Log Likelihood:  -507396.74805463915
# Perplexity:  1393.8669856912798
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: het apparaat gebruik geluid makkelijk zeker gaat snel super mooi tevreden handig goede prima zit prijs lang maken aanrader fijn
#
# Topic 1: laptop het snel muis gebruik handig makkelijk werkt prima usb goede toetsenbord camera gaat deze fijn mooi hand gebruiken zit
#
# Topic 2: telefoon het goede prijs kwaliteit werkt mooi bol snel prima super foto tevreden scherm toestel gebruik perfect com hoesje via
#
# Log Likelihood:  -2908925.0712514883
# Perplexity:  1990.6476130199178
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: apparaat keer weer gekocht het helaas geld goed product jaar gaat kapot werkt kopen eerste nieuwe dit doet maar gebruik
#
# Topic 1: het telefoon goed werkt hoesje zit product batterij gaat slecht kwaliteit tablet gebruik gewoon toestel hoe usb snel alleen zitten
#
# Topic 2: scherm hoesje het goed protector terug telefoon product screenprotector waardoor past bol zit dit jammer foto weer staat helaas glas
#
# Log Likelihood:  -526902.0079218766
# Perplexity:  1452.6895025464732
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: geluid het goede telefoon kwaliteit mooi zit prijs hoesje makkelijk perfect usb zeker prima kabel handig muis gebruik super muziek
#
# Topic 1: snel gebruik het werkt prima makkelijk goede prijs toestel super foto camera telefoon tevreden bol laptop mooi een zeker handig
#
# Topic 2: tandenborstel apparaat het gebruik poetsen tanden makkelijk schoon gaat handig snel vind tevreden fijn ook lang maken super verschillende een
#
# Log Likelihood:  -2826602.311123508
# Perplexity:  1902.2542033520288
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: goed geluid terug het weer product keer werkt binnen bol slecht helaas oortjes kapot dagen besteld nieuwe dit alleen kreeg
#
# Topic 1: het hoesje telefoon scherm goed zit kwaliteit los past helaas product waardoor protector geld screenprotector zitten gebruik slecht blijft gaat
#
# Topic 2: apparaat werkt doet weer jaar bol gekocht keer batterij het toestel laptop kabel com slecht nieuwe printer helaas gewoon cartridge
#
# Log Likelihood:  -454408.8398636606
# Perplexity:  1376.0171534143078
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: apparaat het gebruik makkelijk stofzuiger snel handig maken super fijn schoon maakt gaat tevreden even hij mooi werkt ook een
#
# Topic 1: het telefoon goede snel mooi prijs laptop gebruik kwaliteit prima werkt makkelijk scherm hoesje bol zeker tevreden perfect super muis
#
# Topic 2: geluid het gebruik tandenborstel werkt via goede super prima gaat app muziek zeker makkelijk prijs kabel mooi zit aanrader kwaliteit
#
# Log Likelihood:  -3513911.5283895936
# Perplexity:  2024.4173880448568
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: terug weer keer jaar gekocht kwaliteit bol nieuwe goed kapot apparaat geluid geld maanden slechte gebruik slecht binnen gaat com
#
# Topic 1: werkt goed scherm het product weer screenprotector protector waardoor telefoon weg kabel helaas zit blijft slecht helemaal geld stofzuiger gaat
#
# Topic 2: het hoesje telefoon zit goed product apparaat foto helaas waardoor gebruik plastic mooi werkt gewoon dit los keer ziet niet
#
# Log Likelihood:  -494704.593556446
# Perplexity:  1392.8190158970383
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: apparaat het gebruik makkelijk snel koffie stofzuiger maken handig mooi gaat super schoon ook tevreden zeker maakt lang fijn vind
#
# Topic 1: geluid het goede telefoon mooi prijs werkt prima kwaliteit via makkelijk super hoesje bol zit perfect zeker com tevreden gebruik
#
# Topic 2: het gebruik snel prijs laptop werkt muis goede mooi toestel kwaliteit gaat zeker handig vind prima makkelijk aanrader super fijn
#
# Log Likelihood:  -2879693.4960708264
# Perplexity:  1948.4547933333893
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: bol werkt com product kabel terug weer apparaat toestel het goed printer staat via alleen moeten artikel werkte helaas dit
#
# Topic 1: kwaliteit het apparaat keer kapot jaar geluid goed binnen gekocht gaat weer helaas slecht gebruik kopen product maar nieuwe eerste
#
# Topic 2: scherm hoesje telefoon het goed zit waardoor los zitten blijft past screenprotector gaat geld slecht gewoon glas product waar alleen
#
# Log Likelihood:  -501344.9005454213
# Perplexity:  1365.2610092954712
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: het werkt gebruik laptop snel telefoon scherm prijs prima goede camera foto makkelijk mooi via usb super kwaliteit gaat zit
#
# Topic 1: geluid apparaat het gebruik super prima goede zeker werkt makkelijk prijs tevreden mooi bol snel aanrader koffie product muziek maken
#
# Topic 2: het gebruik makkelijk handig mooi snel goede fijn zit hoesje gaat telefoon stofzuiger apparaat hij prima vind zeker tevreden super
#
# Log Likelihood:  -3391141.8046561806
# Perplexity:  2082.564492433397
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
# Topic 0: scherm goed het werkt screenprotector geld protector slecht geluid weer product gewoon alleen zit telefoon helaas dit glas printer prijs
#
# Topic 1: apparaat terug bol weer product werkt keer gekocht goed helaas com jaar nieuwe kabel eerste toestel het gaat geld slecht
#
# Topic 2: het hoesje telefoon zit kwaliteit goed gaat waardoor product foto los zitten plastic mooi gebruik dit hoe snel slechte artikel
#
# Log Likelihood:  -604071.5906313346
# Perplexity:  1530.80173512583
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 3, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}
